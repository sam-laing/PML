# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We have
# $$
# \sum_{j=1}^{\infty} x_j
# $$

# %%
x = np.linspace(-10, 10, 1000)


def f(t):
    return t**2 + 6 * t - 5


plt.plot(x, f(x))
plt.show()
